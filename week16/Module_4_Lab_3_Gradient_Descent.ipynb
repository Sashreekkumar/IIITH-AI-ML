# %% [markdown]
# <a href="https://colab.research.google.com/github/IITH-STP-ASSIGNMENTS/Basics-of-Linear-Algebra/blob/main/AIML_Module_4_Lab_3_Gradient_Descent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Student Training Prorgam on AIML**
# # Module 4: Perceptron and Gradient Descent
# ## Lab 3: Gradient Descent
#
# Gradient descent is a very important algorithm to understand, as it underpins many of the more advanced algorithms used in Machine Learning and Deep Learning.
#
# A brief overview of the algorithm is
#
#
# *   start with a random initialization of the solution.
# *   incrementally change the solution by moving in the direction of negative gradient of the objective function.
# *   repeat the previous step until some convergence criteria is met.
#
# The key equation for change in weight is:
# $$w^{k+1} \leftarrow w^k - \eta \Delta J$$
#
# In this lab, we will discuss stochastic gradient descent, mini-batch gradient descent and batch gradient descent.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
np.random.seed(42)

# %% [markdown]
# # Creating the Data
#
# Let's generate some data with:
# \begin{equation} y_0= 4 \end{equation}
# \begin{equation} y_1= 3 \end{equation}
#
# and also add some noise to the data.

# %%
X = 2 * np.random.rand(100, 1)
y = 4 + 3 * X + np.random.randn(100, 1)

# %% [markdown]
# Let's also plot the data we just created

# %%
plt.plot(X, y, 'b.')
plt.xlabel('x')
plt.ylabel('y', rotation=0)
# Out:
# Text(0, 0.5, 'y')

# %% [markdown]
# ## Cost Function
#
# The equation for calculating cost function is as shown below. The cost function is only for linear regression. For other algorithms, the cost function will be different and the gradients would have to be derived from the cost functions
#
# \begin{equation}
# J(y_{pred}) = \frac{1}{2} m \sum_{i=1}^{m} (h(y_{pred})^{(i)} - y^{(i)})^2
# \end{equation}

# %%
def cal_cost(y_pred, X, y):
    '''
    Calculates the cost for given X and Y.
    y_pred = Vector of y_preds
    X = Row of X's np.zeros((2, j))
    y = Actual y's np.zeros((2, 1))

    where:
        j is the no of features
    '''

    m = len(y)

    predictions = X.dot(y_pred)
    cost = (1 / 2 * m) * np.sum(np.square(predictions - y))

    return cost

# %% [markdown]
# ## Gradients
#
# \begin{equation}
# y_{pred_0}: = y_{pred_0} -\alpha . (1/m .\sum_{i=1}^{m}(h(y_{pred}^{(i)} - y^{(i)}).X_0^{(i)})
# \end{equation}
# \begin{equation}
# y_{pred_1}: = y_{pred_1} -\alpha . (1/m .\sum_{i=1}^{m}(h(y_{pred}^{(i)} - y^{(i)}).X_0^{(i)})
# \end{equation}
# .
#
# .
#
# .
#
# .
#
# \begin{equation}
# y_{pred_j}: = y_{pred_j} -\alpha . (1/m .\sum_{i=1}^{m}(h(y_{pred}^{(i)} - y^{(i)}).X_0^{(i)})
# \end{equation}

# %%
def gradient_descent(X, y, y_pred, learning_rate=0.01, iterations=100):
    '''
    X = Matrix of X with added bias units
    y = Vector of Y
    y_pred = Vector of y_preds np.random.randn(j, 1)
    learning_rate
    iterations = no of iterations

    Returns the final y_pred vector and array of cost history over no of iterations
    '''

    m = len(y)
    cost_history = np.zeros(iterations)
    y_pred_history = np.zeros((iterations, X.shape[1])) # Initialize with correct shape

    for it in range(iterations):
        prediction = np.dot(X, y_pred)
        y_pred = y_pred - (1 / m) * learning_rate * (X.T.dot((prediction - y)))
        y_pred_history[it,:] = y_pred.T
        cost_history[it]  = cal_cost(y_pred, X, y)

    return y_pred, cost_history, y_pred_history

# %% [markdown]
# Let's do 1000 iterations with a learning rate of 0.01.
# We will start with a random prediction.

# %%
lr = 0.01
n_iter = 1000

y_pred = np.random.randn(2,1)
X_b = np.c_[np.ones((len(X), 1)), X]
y_pred, cost_history, y_pred_history = gradient_descent(X_b, y, y_pred, lr, n_iter)

print('y_pred[0]: {:0.3f}\ny_pred[1]: {:0.3f}'.format(y_pred[0][0], y_pred[1][0]))
print('Final error: {:0.3f}'.format(cost_history[-1]))
# Out:
# y_pred[0]: 3.903
# y_pred[1]: 3.046
# Final error: 4180.375

# %% [markdown]
# Plotting the error vs Number of iterations

# %%
fig, ax = plt.subplots(figsize=(12,8))

ax.set_ylabel('Error')
ax.set_xlabel('Number of iterations')

ax.plot(range(n_iter), cost_history, 'b.')

# %% [markdown]
# Zooming in...

# %%
fig,ax = plt.subplots(figsize=(10,8))
ax.plot(range(200), cost_history[:200], 'b.')

# %% [markdown]
# # Stochastic Gradient Descent

# %% [markdown]
# In Batch Gradient Descent we were considering all the examples for every step of Gradient Descent. But what if our dataset is very huge. Deep learning models crave for data. The more the data the more chances of a model to be good. Suppose our dataset has 5 million examples, then just to take one step the model will have to calculate the gradients of all the 5 million examples. This does not seem an efficient way. To tackle this problem we have Stochastic Gradient Descent. In Stochastic Gradient Descent (SGD), we consider just one example at a time to take a single step.

# %%
def stocashtic_gradient_descent(X, y, y_pred, learning_rate=0.01, iterations=10):
    '''
    X = Matrix of X with added bias units
    y = Vector of Y
    y_pred = Vector of y_pred np.random.randn(j,1)
    learning_rate
    iterations = no of iterations

    Returns the final y_pred vector and array of cost history over no of iterations
    '''

    m = len(y)
    cost_history = np.zeros(iterations)
    # y_pred_history = np.zeros((iterations, X.shape[1])) # No need for history here, removed

    for it in range(iterations):
        cost = 0.0

        for i in range(m):
            rand_ind = np.random.randint(0,m)
            X_i = X[rand_ind, :].reshape(1, X.shape[1])
            y_i = y[rand_ind].reshape(1,1)
            prediction = np.dot(X_i, y_pred)

            y_pred = y_pred - (1 / m) * learning_rate *(X_i.T.dot((prediction - y_i)))
            cost += cal_cost(y_pred, X_i, y_i) # This cost calculation is for a single example, might be better to track average cost or total cost per epoch

        cost_history[it]  = cost # Storing total cost per epoch

    return y_pred, cost_history

# %%
lr = 0.5
n_iter = 50
y_pred = np.random.randn(2, 1)
X_b = np.c_[np.ones((len(X), 1)), X]
y_pred, cost_history = stocashtic_gradient_descent(X_b, y, y_pred, lr, n_iter)

print('y_pred[0]: {:0.3f}\ny_pred[1]: {:0.3f}'.format(y_pred[0][0], y_pred[1][0]))
print('Final error: {:0.3f}'.format(cost_history[-1]))
# Out:
# y_pred[0]: 4.121
# y_pred[1]: 2.755
# Final error: 41.313

# %%
fig, ax = plt.subplots(figsize=(10,8))

ax.set_ylabel('Error')
ax.set_xlabel('Number of iterations')
y_pred = np.random.randn(2,1)

ax.plot(range(n_iter), cost_history, 'b.')

# %% [markdown]
# # Mini Batch Gradient Descent

# %% [markdown]
# We have seen the Batch Gradient Descent. We have also seen the Stochastic Gradient Descent. Batch Gradient Descent can be used for smoother curves. SGD can be used when the dataset is large. Batch Gradient Descent converges directly to minima. SGD converges faster for larger datasets. But, since in SGD we use only one example at a time, we cannot implement the vectorized implementation on it. This can slow down the computations. To tackle this problem, a mixture of Batch Gradient Descent and SGD is used.
# Neither we use all the dataset all at once nor we use the single example at a time. We use a batch of a fixed number of training examples which is less than the actual dataset and call it a mini-batch. Doing this helps us achieve the advantages of both the former variants we saw.

# %%
def minibatch_gradient_descent(X, y, y_pred, learning_rate=0.01, iterations=10, batch_size=20):
    '''
    X = Matrix of X without added bias units
    y = Vector of Y
    y_pred = Vector of y_preds np.random.randn(j, 1)
    learning_rate
    iterations = no of iterations

    Returns the final theta vector and array of cost history over no of iterations
    '''

    m = len(y)
    cost_history = np.zeros(iterations)
    n_batches = int(m / batch_size)
    # y_pred_history = np.zeros((iterations, X.shape[1])) # No need for history here, removed


    for it in range(iterations):
        cost = 0.0
        indices = np.random.permutation(m)
        X = X[indices]
        y = y[indices]

        for i in range(0, m, batch_size):
            X_i = X[i: i + batch_size]
            y_i = y[i: i + batch_size]

            X_i = np.c_[np.ones((len(X_i), 1)), X_i] # Add bias term here
            prediction = np.dot(X_i, y_pred)

            y_pred = y_pred - (1 / m) * learning_rate * (X_i.T.dot((prediction - y_i)))
            cost += cal_cost(y_pred, X_i, y_i) # This cost calculation is for a single batch, might be better to track average cost or total cost per epoch

        cost_history[it]  = cost # Storing total cost per epoch

    return y_pred, cost_history

# %%
lr = 0.1
n_iter = 200
y_pred = np.random.randn(2,1)
y_pred, cost_history = minibatch_gradient_descent(X, y, y_pred, lr, n_iter)

print('y_pred[0]: {:0.3f}\ny_pred[1]: {:0.3f}'.format(y_pred[0][0], y_pred[1][0]))
print('Final error: {:0.3f}'.format(cost_history[-1]))
# Out:
# y_pred[0]: 4.148
# y_pred[1]: 2.827
# Final error: 807.488

# %%
fig, ax = plt.subplots(figsize=(10,8))

ax.set_ylabel('Error')
ax.set_xlabel('Number of iterations')
y_pred = np.random.randn(2,1)

ax.plot(range(n_iter), cost_history, 'b.')

# %% [markdown]
# Things to try out:
#
# 1. Change batch size in mini-batch gradient descent.
# 2. Test all the three out on real datasets.
# 3. Compare the effects of changing learning rate by the same amount in Batch GD, SGD and Mini-batch GD.

# %% [markdown]
# ## **Additional Critical Thinking Question**

# %% [markdown]
# **Which of the following is TRUE, given the optimal learning rate?**
#
#  (i) Batch gradient descent is always guaranteed to converge to the global optimum of a loss function.
#
#  (ii) Stochastic gradient descent is always guaranteed to converge to the global optimum of a loss function.
#
#  (iii) For convex loss functions (i.e. with a bowl shape), batch gradient descent is guaranteed to eventually converge to the global optimum while stochastic gradient descent is not.
#
#  (iv) For convex loss functions (i.e. with a bowl shape), stochastic gradient descent is guaranteed to eventually converge to the global optimum while batch gradient descent is not.
#
#  (v) For convex loss functions (i.e. with a bowl shape), both stochastic gradient descent and batch gradient descent will eventually converge to the global optimum.
#
#  (vi) For convex loss functions (i.e. with a bowl shape), neither stochastic gradient descent nor batch gradient descent are guaranteed to converge to the global optimum.

# %% [markdown]
# The correct answer is **(iii) For convex loss functions (i.e. with a bowl shape), batch gradient descent is guaranteed to eventually converge to the global optimum while stochastic gradient descent is not.**
#
# *   **Batch Gradient Descent (BGD)** uses the gradient of the entire dataset to update the parameters. For a convex loss function, this gradient always points towards the global minimum, ensuring convergence to the global optimum with an appropriate learning rate.
# *   **Stochastic Gradient Descent (SGD)** uses the gradient of a single data point to update the parameters. This introduces noise, causing the optimization path to be more erratic. While SGD will generally move towards the global minimum, it may oscillate around it and not converge precisely to the optimum, even with an optimal learning rate.

# %% [markdown]
# ## Exploring Mini-Batch Size
#
# Let's explore the effect of changing the batch size in mini-batch gradient descent. We'll compare the cost history for different batch sizes.

# %%
# Experimenting with different batch sizes
lr = 0.1
n_iter = 200
batch_sizes = [1, 10, 50, 100]  # Different batch sizes to try

plt.figure(figsize=(12, 8))

for batch_size in batch_sizes:
    y_pred = np.random.randn(2, 1)
    y_pred, cost_history = minibatch_gradient_descent(X, y, y_pred, lr, n_iter, batch_size)
    plt.plot(range(n_iter), cost_history, label=f'Batch Size: {batch_size}')

plt.xlabel('Number of iterations')
plt.ylabel('Error')
plt.title('Effect of Batch Size on Mini-Batch Gradient Descent')
plt.legend()
plt.show()

# %% [markdown]
# ## Testing on a Real Dataset
#
# Now, let's apply all three gradient descent methods to a real dataset. We'll use the Boston housing dataset from scikit-learn.

# %%
from sklearn.datasets import fetch_california_housing
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# Load the dataset
housing = fetch_california_housing()
X_real, y_real = housing.data, housing.target

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_real, y_real, test_size=0.2, random_state=42)

# Standardize the features
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Add bias term to the scaled training data
X_train_b = np.c_[np.ones((len(X_train_scaled), 1)), X_train_scaled]
y_train = y_train.reshape(-1, 1) # Reshape y_train to be a column vector

# --- Batch Gradient Descent on Real Dataset ---
lr_batch = 0.01  # Adjusted learning rate for real dataset
n_iter_batch = 1000
y_pred_batch = np.random.randn(X_train_b.shape[1], 1)
y_pred_batch, cost_history_batch, _ = gradient_descent(X_train_b, y_train, y_pred_batch, lr_batch, n_iter_batch)

print("Batch Gradient Descent Results on California Housing Dataset:")
print('y_pred:', y_pred_batch.T)
print('Final error:', cost_history_batch[-1])

# --- Stochastic Gradient Descent on Real Dataset ---
lr_sgd = 0.001 # Adjusted learning rate for real dataset
n_iter_sgd = 100 # Fewer iterations for SGD
y_pred_sgd = np.random.randn(X_train_b.shape[1], 1) # y_pred should have the correct dimensions
y_pred_sgd, cost_history_sgd = stocashtic_gradient_descent(X_train_b, y_train, y_pred_sgd, lr_sgd, n_iter_sgd)

print("\nStochastic Gradient Descent Results on California Housing Dataset:")
print('y_pred:', y_pred_sgd.T)
print('Final error:', cost_history_sgd[-1])

# --- Mini-Batch Gradient Descent on Real Dataset ---
lr_mini = 0.01 # Adjusted learning rate for real dataset
n_iter_mini = 500 # More iterations for Mini-Batch GD
batch_size_mini = 32 # Example batch size
y_pred_mini = np.random.randn(X_train_b.shape[1], 1) # y_pred should have the correct dimensions
y_pred_mini, cost_history_mini = minibatch_gradient_descent(X_train_scaled, y_train, y_pred_mini, lr_mini, n_iter_mini, batch_size_mini)

print("\nMini-Batch Gradient Descent Results on California Housing Dataset:")
print('y_pred:', y_pred_mini.T)
print('Final error:', cost_history_mini[-1])
# Out:
# Batch Gradient Descent Results on California Housing Dataset:
# y_pred: [[ 2.07181033  0.99678503  0.22448821 -0.41640256  0.37004182  0.0303441
#   -0.05350157  0.00963948  0.02683225]]
# Final error: 83526594.82601169
#
# Stochastic Gradient Descent Results on California Housing Dataset:
# y_pred: [[-0.38712789  0.13283441  0.42129626  0.36147196  1.08678296 -1.85831852
#   -0.67156803  0.54969949  0.62491495]]
# Final error: 114510.81131365185
#
# Mini-Batch Gradient Descent Results on California Housing Dataset:
# y_pred: [[ 2.06555393  0.5304204   0.0413414   0.24715991 -0.08853891 -0.02738124
#   -0.02573    -1.71245571 -1.6495543 ]]
# Final error: 160233.85050180962

# %% [markdown]
# ## Comparing Learning Rates
#
# Finally, let's compare the effect of changing the learning rate by the same amount in Batch GD, SGD, and Mini-batch GD using the synthetic dataset.

# %%
# Comparing learning rates
learning_rates = [0.001, 0.01, 0.1]
n_iter_compare = 100

# Batch Gradient Descent
plt.figure(figsize=(18, 5))
plt.subplot(1, 3, 1)
X_b = np.c_[np.ones((len(X), 1)), X] # Ensure X_b is redefined for the original data

for lr in learning_rates:
    y_pred = np.random.randn(2, 1)
    y_pred, cost_history, _ = gradient_descent(X_b, y, y_pred, lr, n_iter_compare)
    plt.plot(range(n_iter_compare), cost_history, label=f'LR: {lr}')
plt.xlabel('Number of iterations')
plt.ylabel('Error')
plt.title('Batch Gradient Descent')
plt.legend()

# Stochastic Gradient Descent
plt.subplot(1, 3, 2)
for lr in learning_rates:
    y_pred = np.random.randn(2, 1)
    y_pred, cost_history = stocashtic_gradient_descent(X_b, y, y_pred, lr, n_iter_compare)
    plt.plot(range(n_iter_compare), cost_history, label=f'LR: {lr}')
plt.xlabel('Number of iterations')
plt.ylabel('Error')
plt.title('Stochastic Gradient Descent')
plt.legend()

# Mini-Batch Gradient Descent
plt.subplot(1, 3, 3)
batch_size = 20
for lr in learning_rates:
    y_pred = np.random.randn(2, 1)
    # Pass X without the bias term to minibatch_gradient_descent
    y_pred, cost_history = minibatch_gradient_descent(X, y, y_pred, lr, n_iter_compare, batch_size)
    plt.plot(range(n_iter_compare), cost_history, label=f'LR: {lr}')
plt.xlabel('Number of iterations')
plt.ylabel('Error')
plt.title('Mini-Batch Gradient Descent')
plt.legend()

plt.tight_layout()
plt.show()
